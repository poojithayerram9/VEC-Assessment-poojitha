# %% [markdown]
# <a href="https://colab.research.google.com/github/poojithayerram9/VEC-Assessment-poojitha/blob/main/ToPredictConsumerPriceIndex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Importing Required Libraries**

# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # **Collecting And Reading The Dataset**

# %%
df=pd.read_csv('/content/archive (1) (3).zip')

# %% [markdown]
# # **Performing Different Operations To Understand Data**

# %%
df.head()
# Out:
#         Sector  Year     Month  Cereals and products  Meat and fish    Egg  \
# 0        Rural  2013   January                 107.5          106.3  108.1
# 1        Urban  2013   January                 110.5          109.1  113.0
# 2  Rural+Urban  2013   January                 108.4          107.3  110.0
# 3        Rural  2013  February                 109.2          108.7  110.2
# 4        Urban  2013  February                 112.9          112.9  116.9
#
#    Milk and products  Oils and fats  Fruits  Vegetables  ...  Housing  \
# 0              104.9          106.1   103.9       101.9  ...      NaN
# 1              103.6          103.4   102.3       102.9  ...    100.3
# 2              104.4          105.1   103.2       102.2  ...    100.3
# 3              105.4          106.7   104.0       102.4  ...      NaN
# 4              104.0          103.5   103.1       104.9  ...    100.4
#
#    Fuel and light  Household goods and services  Health  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 369 entries, 0 to 368
# Data columns (total 30 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Sector                               369 non-null    object
#  1   Year                                 369 non-null    int64
#  2   Month                                369 non-null    object
#  3   Cereals and products                 366 non-null    float64
#  4   Meat and fish                        363 non-null    float64
#  5   Egg                                  366 non-null    float64
#  6   Milk and products                    366 non-null    float64
#  7   Oils and fats                        366 non-null    float64
#  8   Fruits                               366 non-null    float64
#  9   Vegetables                           366 non-null    float64
#  10  Pulses and products                  366 non-null    float64
# ...

# %%
df.describe()
# Out:
#               Year  Cereals and products  Meat and fish         Egg  \
# count   369.000000            366.000000     363.000000  366.000000
# mean   2017.666667            136.381148     155.778788  140.528415
# std       3.001811             14.674445      33.057329   22.416485
# min    2013.000000            107.500000     106.300000  102.700000
# 25%    2015.000000            124.125000     130.050000  122.025000
# 50%    2018.000000            135.750000     144.100000  135.300000
# 75%    2020.000000            146.175000     190.600000  160.850000
# max    2023.000000            174.800000     223.400000  197.000000
#
#        Milk and products  Oils and fats      Fruits  Vegetables  \
# count         366.000000     366.000000  366.000000  366.000000
# mean          140.004098     131.822131  140.582787  155.677049
# std            18.081395      29.887553   17.202886   27.975420
# min           103.600000     101.100000  102.300000  101.400000
# ...

# %%
df.shape
# Out:
# (369, 30)

# %% [markdown]
# # **Handling Missing Values**

# %%
missing_values=df.isnull().sum()
missing_values
# Out:
# Sector                                   0
# Year                                     0
# Month                                    0
# Cereals and products                     3
# Meat and fish                            6
# Egg                                      3
# Milk and products                        3
# Oils and fats                            3
# Fruits                                   3
# Vegetables                               3
# Pulses and products                      3
# Sugar and Confectionery                  3
# Spices                                   3
# Non-alcoholic beverages                  3
# Prepared meals, snacks, sweets etc.      6
# Food and beverages                       3
# Pan, tobacco and intoxicants             6
# Clothing                                 6
# Footwear                                 6
# Clothing and footwear                    6
# Housing                                122
# Fuel and light                           3
# ...

# %%
columns_with_missing=df.columns[df.isnull().any()]

# %%
df.isnull().any()
# Out:
# Sector                                 False
# Year                                   False
# Month                                  False
# Cereals and products                    True
# Meat and fish                           True
# Egg                                     True
# Milk and products                       True
# Oils and fats                           True
# Fruits                                  True
# Vegetables                              True
# Pulses and products                     True
# Sugar and Confectionery                 True
# Spices                                  True
# Non-alcoholic beverages                 True
# Prepared meals, snacks, sweets etc.     True
# Food and beverages                      True
# Pan, tobacco and intoxicants            True
# Clothing                                True
# Footwear                                True
# Clothing and footwear                   True
# Housing                                 True
# ...

# %%
for column in columns_with_missing:
    df[column]=df[column].interpolate(method='linear',limit_direction='both')
print(df[columns_with_missing].isnull().sum())
# Out:
# Cereals and products                     0
# Meat and fish                            0
# Egg                                      0
# Milk and products                        0
# Oils and fats                            0
# Fruits                                   0
# Vegetables                               0
# Pulses and products                      0
# Sugar and Confectionery                  0
# Spices                                   0
# Non-alcoholic beverages                  0
# Prepared meals, snacks, sweets etc.      0
# Food and beverages                       0
# Pan, tobacco and intoxicants             0
# Clothing                                 0
# Footwear                                 0
# Clothing and footwear                    0
# Housing                                122
# Fuel and light                           0
# Household goods and services             0
# Health                                   0
# Transport and communication              0
# ...

# %%
df.duplicated().any()
# Out:
# False

# %% [markdown]
# # **Label Encoding**

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df.Sector=le.fit_transform(df.Sector)

# %%
df.head()
# Out:
#    Sector  Year     Month  Cereals and products  Meat and fish    Egg  \
# 0       0  2013   January                 107.5          106.3  108.1
# 1       2  2013   January                 110.5          109.1  113.0
# 2       1  2013   January                 108.4          107.3  110.0
# 3       0  2013  February                 109.2          108.7  110.2
# 4       2  2013  February                 112.9          112.9  116.9
#
#    Milk and products  Oils and fats  Fruits  Vegetables  ...  Housing  \
# 0              104.9          106.1   103.9       101.9  ...      NaN
# 1              103.6          103.4   102.3       102.9  ...    100.3
# 2              104.4          105.1   103.2       102.2  ...    100.3
# 3              105.4          106.7   104.0       102.4  ...      NaN
# 4              104.0          103.5   103.1       104.9  ...    100.4
#
#    Fuel and light  Household goods and services  Health  \
# 0           105.5                         104.8   104.0
# ...

# %%
df.Month=le.fit_transform(df.Month)

# %%
df.head()
# Out:
#    Sector  Year  Month  Cereals and products  Meat and fish    Egg  \
# 0       0  2013      4                 107.5          106.3  108.1
# 1       2  2013      4                 110.5          109.1  113.0
# 2       1  2013      4                 108.4          107.3  110.0
# 3       0  2013      3                 109.2          108.7  110.2
# 4       2  2013      3                 112.9          112.9  116.9
#
#    Milk and products  Oils and fats  Fruits  Vegetables  ...  Housing  \
# 0              104.9          106.1   103.9       101.9  ...      NaN
# 1              103.6          103.4   102.3       102.9  ...    100.3
# 2              104.4          105.1   103.2       102.2  ...    100.3
# 3              105.4          106.7   104.0       102.4  ...      NaN
# 4              104.0          103.5   103.1       104.9  ...    100.4
#
#    Fuel and light  Household goods and services  Health  \
# 0           105.5                         104.8   104.0
# ...

# %%
df.Housing=le.fit_transform(df.Housing)

# %%
df.head()
# Out:
#    Sector  Year  Month  Cereals and products  Meat and fish    Egg  \
# 0       0  2013      4                 107.5          106.3  108.1
# 1       2  2013      4                 110.5          109.1  113.0
# 2       1  2013      4                 108.4          107.3  110.0
# 3       0  2013      3                 109.2          108.7  110.2
# 4       2  2013      3                 112.9          112.9  116.9
#
#    Milk and products  Oils and fats  Fruits  Vegetables  ...  Housing  \
# 0              104.9          106.1   103.9       101.9  ...      116
# 1              103.6          103.4   102.3       102.9  ...        1
# 2              104.4          105.1   103.2       102.2  ...        1
# 3              105.4          106.7   104.0       102.4  ...      116
# 4              104.0          103.5   103.1       104.9  ...        2
#
#    Fuel and light  Household goods and services  Health  \
# 0           105.5                         104.8   104.0
# ...

# %% [markdown]
# # **Data Visualisation**

# %%
plt.scatter(df.Sector,df.Month)

# %%
sns.displot(df['Month'])

# %%
sns.jointplot(x=df['Sector'],y=df['Month'],kind="kde")

# %%
sns.jointplot(x=df['Sector'],y=df['Month'])

# %%
df.corr()
# Out:
#                                            Sector          Year     Month  \
# Sector                               1.000000e+00 -1.010924e-15 -0.000815
# Year                                -1.010924e-15  1.000000e+00 -0.032056
# Month                               -8.154162e-04 -3.205578e-02  1.000000
# Cereals and products                 3.591838e-02  9.569660e-01 -0.007031
# Meat and fish                        3.486463e-02  9.613489e-01 -0.003607
# Egg                                  2.933300e-02  9.405815e-01 -0.041712
# Milk and products                   -1.501699e-02  9.798626e-01 -0.004026
# Oils and fats                       -1.215980e-01  8.678606e-01 -0.012500
# Fruits                              -1.354822e-02  9.205542e-01 -0.020732
# Vegetables                           2.297932e-01  5.350551e-01  0.206105
# Pulses and products                  6.881269e-03  6.110112e-01  0.002262
# Sugar and Confectionery             -6.920856e-03  7.501273e-01  0.022539
# ...

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # **Seperating Data Into Dependent And Independent variables**

# %%
x=df.iloc[:,0:19]
x
# Out:
#      Sector  Year  Month  Cereals and products  Meat and fish    Egg  \
# 0         0  2013      4                 107.5          106.3  108.1
# 1         2  2013      4                 110.5          109.1  113.0
# 2         1  2013      4                 108.4          107.3  110.0
# 3         0  2013      3                 109.2          108.7  110.2
# 4         2  2013      3                 112.9          112.9  116.9
# ..      ...   ...    ...                   ...            ...    ...
# 364       2  2023      7                 174.7          212.2  177.2
# 365       1  2023      7                 174.4          207.7  175.2
# 366       0  2023      0                 173.3          206.9  167.9
# 367       2  2023      0                 174.8          213.7  172.4
# 368       1  2023      0                 173.8          209.3  169.6
#
#      Milk and products  Oils and fats  Fruits  Vegetables  \
# 0                104.9          106.1   103.9       101.9
# ...

# %%
y=df.iloc[:,-1]
y
# Out:
# 0      105.1
# 1      104.0
# 2      104.6
# 3      105.8
# 4      104.7
#        ...
# 364    176.3
# 365    177.2
# 366    178.8
# 367    177.4
# 368    178.1
# Name: General index, Length: 369, dtype: float64

# %% [markdown]
# # **Splitting Data Into Train And Test Data**

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
x_train
# Out:
#      Sector  Year  Month  Cereals and products  Meat and fish    Egg  \
# 163       2  2017      5                 132.8          148.4  129.4
# 12        0  2013      9                 110.9          109.8  105.9
# 13        2  2013      9                 115.4          114.2  102.7
# 160       2  2017      6                 132.9          148.7  128.3
# 84        0  2015      9                 123.5          127.1  117.3
# ..      ...   ...    ...                   ...            ...    ...
# 299       1  2021      9                 146.3          200.5  170.3
# 22        2  2013      1                 118.3          120.4  112.7
# 72        0  2015      4                 123.1          123.1  122.1
# 15        0  2013      6                 112.3          112.1  108.1
# 168       0  2017     13                 135.2          142.0  130.5
#
#      Milk and products  Oils and fats  Fruits  Vegetables  \
# 163              137.7          113.4   139.4       175.1
# ...

# %%
y_train
# Out:
# 163    131.8
# 12     107.2
# 13     106.6
# 160    129.9
# 84     122.4
#        ...
# 299    160.4
# 22     112.7
# 72     120.3
# 15     108.9
# 168    137.6
# Name: General index, Length: 295, dtype: float64

# %% [markdown]
# # **Model Building**

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.linear_model import LinearRegression,Lasso
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
ls=Lasso()
ls.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.291e+01, tolerance: 1.209e+01
#   model = cd_fast.enet_coordinate_descent(
# Lasso()

# %%
from sklearn.neighbors import KNeighborsRegressor
knn=KNeighborsRegressor()
knn.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr=GradientBoostingRegressor()
gbr.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
from sklearn.ensemble import AdaBoostRegressor
adb=AdaBoostRegressor()
adb.fit(x_train,y_train)
# Out:
# AdaBoostRegressor()

# %%
acc16=adb.score(x_train,y_train)
acc16
# Out:
# 0.9980969374327163

# %%
acc15=gbr.score(x_train,y_train)
acc15
# Out:
# 0.9999179716186185

# %%
acc14=knn.score(x_train,y_train)
acc14
# Out:
# 0.9982665627521207

# %%
acc13=ls.score(x_train,y_train)
acc13
# Out:
# 0.9990414793701204

# %%
acc12=rfr.score(x_train,y_train)
acc12
# Out:
# 0.9998440735175824

# %%
acc11=lr.score(x_train,y_train)
acc11
# Out:
# 0.9995837860533128

# %% [markdown]
# # **Hyperparameter Tuning**

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.datasets import make_regression

# %%
x,y=make_regression(n_samples=1000,n_features=10,noise=0.1,random_state=42)

# %%
model=RandomForestRegressor()

# %%
param_grid={
    'n_estimators':[100,200,300],
    'max_depth':[None,10,20],
    'min_samples_split':[2,5,10],
    'min_samples_leaf':[1,2,4]
}

# %%
grid_search=GridSearchCV(estimator=model,param_grid=param_grid,cv=5,scoring='neg_mean_squared_error')

# %%
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [None, 10, 20],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 200, 300]},
#              scoring='neg_mean_squared_error')

# %%
print("Best hyperparameters:",grid_search.best_params_)
# Out:
# Best hyperparameters: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}

# %% [markdown]
# # **Storing The Model**

# %%
import pickle
import warnings
pickle.dump(ls,open('model.pkl','wb'))

# %% [markdown]
# # **Making Prediction Using Stored Model**
